# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - 정밀도와 재현율은 trade off 관계

# %% [markdown]
# ![image.png](attachment:image.png)
